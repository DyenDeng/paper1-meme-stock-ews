# %%
"""
Logistic Regression 完整版
===========================
数据:   data/merged_data_scaled_CLEAN.parquet
标签:   EWS_5min (改这里切换)
训练:   ~ 2021-01-25
测试:   2021-01-28 ~ 02-28
"""

import pandas as pd
import numpy as np
import json
import os
import matplotlib.pyplot as plt
import shap
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (roc_auc_score, average_precision_score,
                             f1_score, precision_score, recall_score,
                             classification_report, precision_recall_curve)

# ─── 配置 ────────────────────────────────────────────────────────────────────
DATA_FILE   = 'data/merged_data_scaled_CLEAN.parquet'
GROUPS_FILE = 'data/feature_groups_CLEAN.json'
TARGET      = 'EWS_30min'   # <- 改成 EWS_15min / EWS_30min

TRAIN_END  = '2021-01-25 23:59:59'
TEST_START = '2021-01-28 00:00:00'
TEST_END   = '2021-02-28 23:59:59'

LEAKAGE_FEATURES = [
    'is_episode_t', 'is_luld', 'is_anomaly',
    'is_price_spike', 'is_volume_surge',
    'thread_concentration', 'is_official_halt',
]

OUT_DIR = f'results_lr_{TARGET}'
os.makedirs(OUT_DIR, exist_ok=True)
print(f'输出目录: {OUT_DIR}/')

LR_PARAMS = {
    'C': 1.0,
    'max_iter': 1000,
    'solver': 'lbfgs',
    'random_state': 42,
    'n_jobs': -1,
}

# ─── 1. 加载数据 ─────────────────────────────────────────────────────────────
df = pd.read_parquet(DATA_FILE)
df['timestamp'] = pd.to_datetime(df['timestamp'])
df = df.sort_values('timestamp').reset_index(drop=True)

with open(GROUPS_FILE, 'r') as f:
    feature_groups = json.load(f)

print(f"数据维度: {df.shape}")
print(f"时间范围: {df['timestamp'].min()} ~ {df['timestamp'].max()}")
print(f"正样本数: {int(df[TARGET].sum())}  ({df[TARGET].mean()*100:.2f}%)")

# ─── 2. 官方halt滞后特征 ─────────────────────────────────────────────────────
halt_lag = [c for c in ['is_official_halt_lag1', 'is_official_halt_lag2']
            if c in df.columns]
if halt_lag:
    feature_groups['market'] = list(feature_groups.get('market', [])) + halt_lag
    print(f"  ✓ market组加入: {halt_lag}")

# ─── 3. 划分数据集 ───────────────────────────────────────────────────────────
train_mask = df['timestamp'] <= TRAIN_END
test_mask  = (df['timestamp'] >= TEST_START) & (df['timestamp'] <= TEST_END)

y_train = df.loc[train_mask, TARGET]
y_test  = df.loc[test_mask,  TARGET]

spw = (y_train == 0).sum() / y_train.sum()

print(f"\n训练集: {train_mask.sum():,} 样本 | 正样本: {int(y_train.sum())} ({y_train.mean()*100:.2f}%)")
print(f"测试集: {test_mask.sum():,} 样本  | 正样本: {int(y_test.sum())} ({y_test.mean()*100:.2f}%)")

# ─── 4. Ablation 实验配置 ────────────────────────────────────────────────────
EXPERIMENTS = {
    # ── 累加式 ablation ──────────────────────────────────────────────────────
    'baseline_market':        ['market'],
    'M1_add_cascade':         ['market', 'cascade'],
    'M2_add_network':         ['market', 'cascade', 'network'],
    'M3_add_temporal':        ['market', 'cascade', 'network', 'temporal'],
    'M4_add_text':            ['market', 'cascade', 'network', 'temporal', 'text'],
    'full_with_coordination': ['market', 'cascade', 'network', 'temporal', 'text',
                               'burstiness', 'user_overlap', 'text_duplication'],

    # ── 隔离式 ablation（baseline_market 同时作为 market-only）──────────────
    'iso_reddit_volume_only': ['temporal'],
    'iso_text_only':          ['text'],
    'iso_network_only':       ['network'],
    'iso_coordination_only':  ['burstiness', 'user_overlap', 'text_duplication'],
}

def get_features(groups_list):
    feats = []
    for g in groups_list:
        feats.extend(feature_groups.get(g, []))
    feats = [f for f in dict.fromkeys(feats) if f in df.columns]
    feats = [f for f in feats if f not in LEAKAGE_FEATURES]
    return feats

# ─── 5. 运行实验 ─────────────────────────────────────────────────────────────
print("\n" + "="*65)
print("  Ablation 实验")
print("="*65)

results = []
models  = {}

for exp_name, groups in EXPERIMENTS.items():
    features = get_features(groups)
    if not features:
        continue

    X_train = df.loc[train_mask, features].fillna(0)
    X_test  = df.loc[test_mask,  features].fillna(0)

    model = LogisticRegression(**LR_PARAMS, class_weight={0: 1, 1: spw})
    model.fit(X_train, y_train)

    y_prob = model.predict_proba(X_test)[:, 1]
    y_pred = (y_prob >= 0.5).astype(int)

    pr_auc  = average_precision_score(y_test, y_prob)
    roc_auc = roc_auc_score(y_test, y_prob)
    f1      = f1_score(y_test, y_pred, zero_division=0)
    recall  = recall_score(y_test, y_pred, zero_division=0)

    print(f"\n  {exp_name}")
    print(f"    特征数: {len(features):>3} | PR-AUC: {pr_auc:.4f} | "
          f"ROC-AUC: {roc_auc:.4f} | F1: {f1:.4f} | Recall: {recall:.4f}")

    results.append({
        'experiment': exp_name,
        'n_features': len(features),
        'pr_auc': pr_auc,
        'roc_auc': roc_auc,
        'f1': f1,
        'recall': recall,
    })
    models[exp_name] = (model, features, y_prob)

# ─── 6. 汇总 ─────────────────────────────────────────────────────────────────
print("\n" + "="*65)
print("  汇总结果")
print("="*65)

results_df = pd.DataFrame(results)
print(results_df.to_string(index=False, float_format=lambda x: f'{x:.4f}'))
results_df.to_csv(f'{OUT_DIR}/ablation_results.csv', index=False)
print(f"\n✓ 保存: {OUT_DIR}/ablation_results.csv")

if len(results) >= 2:
    full = results[-1]
    prev = results[-2]
    lift = full['pr_auc'] - prev['pr_auc']
    print(f"\n  Coordination 边际贡献: {lift:+.4f} ({lift/prev['pr_auc']*100:+.1f}%)")

# ─── 7. 最优模型详细评估 ─────────────────────────────────────────────────────
best_exp  = max(results, key=lambda x: x['pr_auc'])['experiment']
model, features, y_prob = models[best_exp]

print(f"\n{'='*65}")
print(f"  最优模型: {best_exp}")
print(f"{'='*65}")

thresholds = np.arange(0.02, 0.70, 0.01)
f1s   = [f1_score(y_test, (y_prob >= t).astype(int), zero_division=0)
         for t in thresholds]
best_t = thresholds[np.argmax(f1s)]
y_pred = (y_prob >= best_t).astype(int)

print(f"\n  最优阈值: {best_t:.2f}")
print(f"  PR-AUC : {average_precision_score(y_test, y_prob):.4f}  ⭐")
print(f"  ROC-AUC: {roc_auc_score(y_test, y_prob):.4f}")
print(f"\n{classification_report(y_test, y_pred, digits=3, zero_division=0)}")

# 特征系数（逻辑回归用系数代替SHAP）
coef_df = pd.DataFrame({
    'feature': features,
    'coefficient': np.abs(model.coef_[0])
}).sort_values('coefficient', ascending=False).head(20).reset_index(drop=True)
coef_df.index += 1
coef_df.insert(0, 'rank', coef_df.index)

print(f"\n  Top 20 特征系数 (|coef|):")
print(coef_df.to_string(index=False, float_format=lambda x: f'{x:.4f}'))
coef_df.to_csv(f'{OUT_DIR}/shap_importance.csv', index=False)

# 每日预测
result_df = df.loc[test_mask, ['timestamp', TARGET]].copy()
result_df['prob'] = y_prob
result_df['pred'] = y_pred
result_df['date'] = result_df['timestamp'].dt.date

daily = result_df.groupby('date').agg(
    true_events=(TARGET, 'sum'),
    predicted=('pred', 'sum'),
    max_prob=('prob', 'max'),
)
print(f"\n  每日预测:")
print(daily.to_string())
daily.to_csv(f'{OUT_DIR}/daily_prediction.csv')

# PR 曲线图
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

prec, rec, _ = precision_recall_curve(y_test, y_prob)
axes[0].plot(rec, prec, color='steelblue', lw=2)
axes[0].axhline(y=y_test.mean(), color='gray', linestyle='--',
                label=f'Baseline ({y_test.mean():.3f})')
axes[0].scatter(recall_score(y_test, y_pred, zero_division=0),
                precision_score(y_test, y_pred, zero_division=0),
                color='red', s=80, zorder=5, label=f'Best t={best_t:.2f}')
axes[0].set_xlabel('Recall'); axes[0].set_ylabel('Precision')
axes[0].set_title(f'PR Curve - {best_exp}')
axes[0].legend(); axes[0].grid(alpha=0.3)

axes[1].plot(results_df['experiment'], results_df['pr_auc'], 'o-',
             color='steelblue', lw=2)
axes[1].set_ylabel('PR-AUC')
axes[1].set_title('Incremental Ablation')
axes[1].tick_params(axis='x', rotation=30)
axes[1].grid(alpha=0.3)

plt.tight_layout()
plt.savefig(f'{OUT_DIR}/ablation_results.png', dpi=150, bbox_inches='tight')
plt.show()
print(f"\n✓ 所有文件已保存到: {OUT_DIR}/")
# Out:
# 输出目录: results_lr_EWS_30min/
# 数据维度: (59146, 113)
# 时间范围: 2019-07-01 13:25:00 ~ 2021-06-30 23:55:00
# 正样本数: 4199  (7.10%)
#   ✓ market组加入: ['is_official_halt_lag1', 'is_official_halt_lag2']
#
# 训练集: 41,816 样本 | 正样本: 2363 (5.65%)
# 测试集: 3,759 样本  | 正样本: 578 (15.38%)
#
# =================================================================
#   Ablation 实验
# =================================================================
#
#   baseline_market
#     特征数:  17 | PR-AUC: 0.3988 | ROC-AUC: 0.7467 | F1: 0.2640 | Recall: 0.9879
#
#   M1_add_cascade
#     特征数:  29 | PR-AUC: 0.4069 | ROC-AUC: 0.7337 | F1: 0.2631 | Recall: 0.9706
#
#   M2_add_network
#     特征数:  42 | PR-AUC: 0.3985 | ROC-AUC: 0.7265 | F1: 0.2635 | Recall: 0.9723
#
#   M3_add_temporal
#     特征数:  77 | PR-AUC: 0.3984 | ROC-AUC: 0.7320 | F1: 0.2749 | Recall: 0.9567
#
#   M4_add_text
#     特征数:  87 | PR-AUC: 0.3990 | ROC-AUC: 0.7336 | F1: 0.2738 | Recall: 0.9550
#
#   full_with_coordination
#     特征数: 102 | PR-AUC: 0.3990 | ROC-AUC: 0.7355 | F1: 0.2742 | Recall: 0.9550
#
#   iso_reddit_volume_only
#     特征数:  35 | PR-AUC: 0.3708 | ROC-AUC: 0.7212 | F1: 0.2846 | Recall: 0.9567
#
#   iso_text_only
#     特征数:  10 | PR-AUC: 0.2496 | ROC-AUC: 0.6867 | F1: 0.2677 | Recall: 1.0000
#
#   iso_network_only
#     特征数:  13 | PR-AUC: 0.3485 | ROC-AUC: 0.6891 | F1: 0.2717 | Recall: 1.0000
#
#   iso_coordination_only
#     特征数:  15 | PR-AUC: 0.3617 | ROC-AUC: 0.6843 | F1: 0.2707 | Recall: 1.0000
#
# =================================================================
#   汇总结果
# =================================================================
#             experiment  n_features  pr_auc  roc_auc     f1  recall
#        baseline_market          17  0.3988   0.7467 0.2640  0.9879
#         M1_add_cascade          29  0.4069   0.7337 0.2631  0.9706
#         M2_add_network          42  0.3985   0.7265 0.2635  0.9723
#        M3_add_temporal          77  0.3984   0.7320 0.2749  0.9567
#            M4_add_text          87  0.3990   0.7336 0.2738  0.9550
# full_with_coordination         102  0.3990   0.7355 0.2742  0.9550
# iso_reddit_volume_only          35  0.3708   0.7212 0.2846  0.9567
#          iso_text_only          10  0.2496   0.6867 0.2677  1.0000
#       iso_network_only          13  0.3485   0.6891 0.2717  1.0000
#  iso_coordination_only          15  0.3617   0.6843 0.2707  1.0000
#
# ✓ 保存: results_lr_EWS_30min/ablation_results.csv
#
#   Coordination 边际贡献: +0.0131 (+3.8%)
#
# =================================================================
#   最优模型: M1_add_cascade
# =================================================================
#
#   最优阈值: 0.69
#   PR-AUC : 0.4069  ⭐
#   ROC-AUC: 0.7337
#
#               precision    recall  f1-score   support
#
#            0      0.930     0.100     0.181      3181
#            1      0.162     0.958     0.277       578
#
#     accuracy                          0.232      3759
#    macro avg      0.546     0.529     0.229      3759
# weighted avg      0.812     0.232     0.196      3759
#
#
#   Top 20 特征系数 (|coef|):
#  rank                  feature  coefficient
#     1                     high       6.9764
#     2                      low       6.0136
#     3             high_lag5min       3.0130
#     4              low_lag5min       2.2654
#     5        cascade_size_mean       1.0856
#     6                    close       0.9726
#     7         cascade_size_max       0.9726
#     8         cascade_size_sum       0.7527
#     9            cascade_count       0.7055
#    10            close_lag5min       0.6829
#    11                     vwap       0.5444
#    12              returns_std       0.5430
#    13  structural_virality_max       0.5207
#    14              trade_count       0.4765
#    15 structural_virality_mean       0.4089
#    16                     open       0.2275
#    17      cascade_breadth_max       0.1694
#    18        cascade_depth_max       0.1643
#    19    is_official_halt_lag1       0.1417
#    20     cascade_breadth_mean       0.1272
#
#   每日预测:
#             true_events  predicted  max_prob
# date
# 2021-01-28          117        187  1.000000
# 2021-01-29           38        174  1.000000
# 2021-02-01           50        178  1.000000
# 2021-02-02           58        188  1.000000
# 2021-02-03           28        173  0.998045
# 2021-02-04           11        175  0.998404
# 2021-02-05           35        143  0.999998
# 2021-02-08           26        177  0.988134
# 2021-02-09           11        175  0.955794
# 2021-02-10           14        137  0.975635
# 2021-02-11           15        176  0.929865
# 2021-02-12           14        144  0.918939
# 2021-02-16            7        169  0.886687
# 2021-02-17            0        161  0.882347
# 2021-02-18            8        159  0.956798
# 2021-02-19           12        136  0.853299
# 2021-02-22           21        127  0.862697
# 2021-02-23            7        136  0.836011
# 2021-02-24           51        142  1.000000
# 2021-02-25           39        182  1.000000
# 2021-02-26           16        177  0.999997
# ✓ 所有文件已保存到: results_lr_EWS_30min/
