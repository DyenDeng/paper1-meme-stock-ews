# %%
"""
Feature Group 检查器 — AMC
====================
查看每个组有哪些特征，并标注潜在leakage风险
"""
import pandas as pd
import numpy as np
import json

GROUPS_FILE = 'data/feature_groups_amc_CLEAN.json'
DATA_FILE   = 'data/merged_data_amc_scaled_CLEAN.parquet'
TARGET      = 'EWS_15min'

# 已知leakage特征
KNOWN_LEAKAGE = {
    'is_episode_t', 'is_luld', 'is_anomaly',
    'is_price_spike', 'is_volume_surge', 'thread_concentration','is_official_halt'
}

with open(GROUPS_FILE, 'r') as f:
    feature_groups = json.load(f)

df = pd.read_parquet(DATA_FILE)
df['timestamp'] = pd.to_datetime(df['timestamp'])

print("=" * 70)
print(f"  Feature Group 检查报告 — AMC")
print(f"  数据维度: {df.shape}  |  目标: {TARGET}")
print("=" * 70)

for group, feats in feature_groups.items():
    exist   = [f for f in feats if f in df.columns]
    missing = [f for f in feats if f not in df.columns]

    print(f"\n【{group.upper()}】  ({len(exist)} 个特征)")
    print("-" * 70)
    print(f"  {'特征名':<35} {'与EWS相关性':>10}  {'状态'}")
    print("-" * 70)

    for f in exist:
        corr = df[f].corr(df[TARGET])

        if f in KNOWN_LEAKAGE:
            status = "🔴 LEAKAGE 已知"
        elif abs(corr) > 0.4:
            status = "🟠 相关性极高，检查"
        elif abs(corr) > 0.2:
            status = "🟡 相关性偏高，留意"
        elif df[f].nunique() <= 1:
            status = "⚫ 常数列，无用"
        elif df[f].isna().mean() > 0.5:
            status = "⚪ 缺失>50%"
        else:
            status = "✅ 正常"

        corr_str = f"{corr:>+.3f}" if not np.isnan(corr) else "   NaN"
        print(f"  {f:<35} {corr_str:>10}  {status}")

    if missing:
        print(f"\n  ⚠️  以下特征在数据中不存在: {missing}")

print("\n" + "=" * 70)
print(f"  总特征数: {sum(len(v) for v in feature_groups.values())}")
print(f"  已知leakage: {KNOWN_LEAKAGE}")
print("=" * 70)
# Out:
# ======================================================================
#   Feature Group 检查报告 — AMC
#   数据维度: (67510, 113)  |  目标: EWS_15min
# ======================================================================
#
# 【MARKET】  (22 个特征)
# ----------------------------------------------------------------------
#   特征名                                    与EWS相关性  状态
# ----------------------------------------------------------------------
#   close                                   +0.018  ✅ 正常
#   high                                    +0.020  ✅ 正常
#   low                                     +0.017  ✅ 正常
#   trade_count                             +0.074  ✅ 正常
#   open                                    +0.018  ✅ 正常
#   vwap                                    +0.019  ✅ 正常
#   returns                                 +0.014  ✅ 正常
#   returns_mean                            +0.034  ✅ 正常
#   returns_std                             +0.073  ✅ 正常
#   returns_z                               -0.000  ✅ 正常
#   is_luld                                 +0.158  🔴 LEAKAGE 已知
#   is_price_spike                          +0.233  🔴 LEAKAGE 已知
#   is_anomaly                              +0.497  🔴 LEAKAGE 已知
#   is_episode_t                            +0.530  🔴 LEAKAGE 已知
#   close_lag5min                           +0.018  ✅ 正常
#   returns_lag5min                         +0.007  ✅ 正常
#   high_lag5min                            +0.019  ✅ 正常
#   low_lag5min                             +0.018  ✅ 正常
#   returns_z_lag5min                       -0.003  ✅ 正常
#   is_official_halt                        +0.121  🔴 LEAKAGE 已知
#   is_official_halt_lag1                   +0.100  ✅ 正常
#   is_official_halt_lag2                   +0.077  ✅ 正常
#
# 【CASCADE】  (12 个特征)
# ----------------------------------------------------------------------
#   特征名                                    与EWS相关性  状态
# ----------------------------------------------------------------------
#   cascade_size_mean                       +0.023  ✅ 正常
#   cascade_size_max                        +0.029  ✅ 正常
#   cascade_size_sum                        +0.043  ✅ 正常
#   cascade_depth_mean                      +0.027  ✅ 正常
#   cascade_depth_max                       +0.036  ✅ 正常
#   cascade_breadth_mean                    +0.022  ✅ 正常
#   cascade_breadth_max                     +0.029  ✅ 正常
#   structural_virality_mean                +0.028  ✅ 正常
#   structural_virality_max                 +0.034  ✅ 正常
#   adoption_speed_mean                     +0.030  ✅ 正常
#   adoption_speed_max                      +0.055  ✅ 正常
#   cascade_count                           +0.073  ✅ 正常
#
# 【NETWORK】  (13 个特征)
# ----------------------------------------------------------------------
#   特征名                                    与EWS相关性  状态
# ----------------------------------------------------------------------
#   node_count                              +0.074  ✅ 正常
#   edge_count                              +0.058  ✅ 正常
#   density                                 +0.002  ✅ 正常
#   avg_degree                              +0.014  ✅ 正常
#   max_degree                              +0.024  ✅ 正常
#   avg_betweenness                         +0.004  ✅ 正常
#   max_betweenness                         +0.004  ✅ 正常
#   avg_clustering                          -0.003  ✅ 正常
#   max_k_core                              +0.029  ✅ 正常
#   avg_pagerank                            +0.007  ✅ 正常
#   max_pagerank                            +0.008  ✅ 正常
#   num_components                          +0.076  ✅ 正常
#   largest_component_size                  +0.030  ✅ 正常
#
# 【TEMPORAL】  (36 个特征)
# ----------------------------------------------------------------------
#   特征名                                    与EWS相关性  状态
# ----------------------------------------------------------------------
#   volume                                  +0.074  ✅ 正常
#   volume_mean                             +0.021  ✅ 正常
#   volume_std                              +0.036  ✅ 正常
#   volume_z                                +0.191  ✅ 正常
#   is_volume_surge                         +0.251  🔴 LEAKAGE 已知
#   volume_lag5min                          +0.024  ✅ 正常
#   volume_z_lag5min                        +0.051  ✅ 正常
#   post_volume                             +0.069  ✅ 正常
#   comment_volume                          +0.086  ✅ 正常
#   total_volume                            +0.074  ✅ 正常
#   unique_users                            +0.075  ✅ 正常
#   total_score                             +0.028  ✅ 正常
#   avg_score                               +0.006  ✅ 正常
#   max_score                               +0.012  ✅ 正常
#   post_velocity                           +0.023  ✅ 正常
#   comment_velocity                        +0.014  ✅ 正常
#   total_velocity                          +0.024  ✅ 正常
#   post_acceleration                       +0.002  ✅ 正常
#   comment_acceleration                    +0.003  ✅ 正常
#   total_acceleration                      +0.003  ✅ 正常
#   volume_mean_60min                       +0.061  ✅ 正常
#   volume_std_60min                        +0.058  ✅ 正常
#   volume_zscore                           +0.027  ✅ 正常
#   is_burst                                +0.004  ✅ 正常
#   burst_intensity                         +0.037  ✅ 正常
#   post_volume_5min                        +0.069  ✅ 正常
#   comment_volume_5min                     +0.086  ✅ 正常
#   total_volume_5min                       +0.074  ✅ 正常
#   post_volume_15min                       +0.065  ✅ 正常
#   comment_volume_15min                    +0.084  ✅ 正常
#   total_volume_15min                      +0.070  ✅ 正常
#   post_volume_30min                       +0.059  ✅ 正常
#   comment_volume_30min                    +0.081  ✅ 正常
#   total_volume_30min                      +0.065  ✅ 正常
#   user_growth                             +0.062  ✅ 正常
#   pct_posts_under_5sec                    +0.051  ✅ 正常
#
# 【TEXT】  (10 个特征)
# ----------------------------------------------------------------------
#   特征名                                    与EWS相关性  状态
# ----------------------------------------------------------------------
#   sentiment_positive                      +0.018  ✅ 正常
#   sentiment_negative                      +0.018  ✅ 正常
#   sentiment_neutral                       +0.030  ✅ 正常
#   sentiment_compound                      +0.003  ✅ 正常
#   urgency_score                           +0.015  ✅ 正常
#   bullish_keywords                        +0.016  ✅ 正常
#   bearish_keywords                        +0.009  ✅ 正常
#   emoji_density                           +0.014  ✅ 正常
#   caps_ratio                              +0.033  ✅ 正常
#   exclamation_ratio                       +0.012  ✅ 正常
#
# 【BURSTINESS】  (5 个特征)
# ----------------------------------------------------------------------
#   特征名                                    与EWS相关性  状态
# ----------------------------------------------------------------------
#   burstiness_coefficient                  +0.005  ✅ 正常
#   sync_posting_rate                       +0.015  ✅ 正常
#   inter_arrival_mean                      +0.007  ✅ 正常
#   inter_arrival_std                       +0.005  ✅ 正常
#   inter_arrival_min                       +0.005  ✅ 正常
#
# 【USER_OVERLAP】  (5 个特征)
# ----------------------------------------------------------------------
#   特征名                                    与EWS相关性  状态
# ----------------------------------------------------------------------
#   cross_thread_overlap                    -0.002  ✅ 正常
#   multi_thread_user_ratio                 +0.011  ✅ 正常
#   coordinated_group_size                  +0.063  ✅ 正常
#   unique_threads                          +0.074  ✅ 正常
#   thread_concentration                       NaN  🔴 LEAKAGE 已知
#
# 【TEXT_DUPLICATION】  (6 个特征)
# ----------------------------------------------------------------------
#   特征名                                    与EWS相关性  状态
# ----------------------------------------------------------------------
#   exact_duplicate_rate                    +0.014  ✅ 正常
#   fuzzy_duplicate_rate                    -0.001  ✅ 正常
#   unique_text_ratio                       +0.030  ✅ 正常
#   avg_text_similarity                     +0.031  ✅ 正常
#   max_duplicate_count                     +0.040  ✅ 正常
#   duplicate_cluster_size                  +0.040  ✅ 正常
#
# ======================================================================
#   总特征数: 109
#   已知leakage: {'is_price_spike', 'is_official_halt', 'is_episode_t', 'thread_concentration', 'is_volume_surge', 'is_luld', 'is_anomaly'}
# ======================================================================
